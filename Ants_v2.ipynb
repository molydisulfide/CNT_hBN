# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import pandas as pd
import matplotlib.patches as mpatches
import pylab as pb
import matplotlib.ticker as mtick
from matplotlib import cm
from numpy import linspace
from csv import reader
from matplotlib import pyplot
import matplotlib.colors as colors
from matplotlib import rcParams
import matplotlib.gridspec as gridspec
import matplotlib.image as mpimg

# %% [markdown]
# # Ants_v2_2_4
#
# _____________

# %%
Ants_v2_2_4_Vbg_mp60V_Vds_0p1V = pd.read_csv('./Pre_transfer/Ants_v2_2_4_Vbg_mp60V_Vds_0p1V.csv')
Vbg_1 = Ants_v2_2_4_Vbg_mp60V_Vds_0p1V[" Vbg"]
Id_1 = Ants_v2_2_4_Vbg_mp60V_Vds_0p1V[' Id']
Ibg_1 = Ants_v2_2_4_Vbg_mp60V_Vds_0p1V[' Ibg']

Ants_v2_2_4_Vbg_mp60V_Vds_0p5V = pd.read_csv('./Pre_transfer/Ants_v2_2_4_Vbg_mp60V_Vds_0p5V.csv')
Vbg_2 = Ants_v2_2_4_Vbg_mp60V_Vds_0p5V[" Vbg"]
Id_2 = Ants_v2_2_4_Vbg_mp60V_Vds_0p5V[' Id']
Ibg_2 = Ants_v2_2_4_Vbg_mp60V_Vds_0p5V[' Ibg']

Ants_v2_2_4_Vbg_mp60V_Vds_1V = pd.read_csv('./Pre_transfer/Ants_v2_2_4_Vbg_mp60V_Vds_1V.csv')
Vbg_3 = Ants_v2_2_4_Vbg_mp60V_Vds_1V[" Vbg"]
Id_3 = Ants_v2_2_4_Vbg_mp60V_Vds_1V[' Id']
Ibg_3 = Ants_v2_2_4_Vbg_mp60V_Vds_1V[' Ibg']

Ants_v2_2_4_Vbg_mp60V_Vds_2V = pd.read_csv('./Pre_transfer/Ants_v2_2_4_Vbg_mp60V_Vds_2V.csv')
Vbg_4 = Ants_v2_2_4_Vbg_mp60V_Vds_2V[" Vbg"]
Id_4 = Ants_v2_2_4_Vbg_mp60V_Vds_2V[' Id']
Ibg_4 = Ants_v2_2_4_Vbg_mp60V_Vds_2V[' Ibg']

hysteresis = pd.read_csv('./Pre_transfer/hysteresis.csv')
Vbg_5 = hysteresis[" Vbg"]
Id_5 = hysteresis[' Id']
Ibg_5 = hysteresis[' Ibg']

###############IVs#########

Ants_v2_2_4_Vbg_0V_Vds_0tm5V = pd.read_csv('./Pre_transfer/Ants_v2_2_4_Vbg_0V_Vds_0tm5V.csv')
Vd_6 = Ants_v2_2_4_Vbg_0V_Vds_0tm5V[" Vd"]
Id_6 = Ants_v2_2_4_Vbg_0V_Vds_0tm5V[' Id']
Ibg_6 = Ants_v2_2_4_Vbg_0V_Vds_0tm5V[' Ibg']

Ants_v2_2_4_Vbg_neg5V_Vds_0tm5V = pd.read_csv('./Pre_transfer/Ants_v2_2_4_Vbg_neg5V_Vds_0tm5V.csv')
Vd_7 = Ants_v2_2_4_Vbg_neg5V_Vds_0tm5V[" Vd"]
Id_7 = Ants_v2_2_4_Vbg_neg5V_Vds_0tm5V[' Id']
Ibg_7 = Ants_v2_2_4_Vbg_neg5V_Vds_0tm5V[' Ibg']

Ants_v2_2_4_Vbg_neg7p5V_Vds_0tm5V = pd.read_csv('./Pre_transfer/Ants_v2_2_4_Vbg_neg7p5V_Vds_0tm5V.csv')
Vd_8 = Ants_v2_2_4_Vbg_neg7p5V_Vds_0tm5V[" Vd"]
Id_8 = Ants_v2_2_4_Vbg_neg7p5V_Vds_0tm5V[' Id']
Ibg_8 = Ants_v2_2_4_Vbg_neg7p5V_Vds_0tm5V[' Ibg']

Ants_v2_2_4_Vbg_neg10V_Vds_0tm5V = pd.read_csv('./Pre_transfer/Ants_v2_2_4_Vbg_neg10V_Vds_0tm5V.csv')
Vd_9 = Ants_v2_2_4_Vbg_neg10V_Vds_0tm5V[" Vd"]
Id_9 = Ants_v2_2_4_Vbg_neg10V_Vds_0tm5V[' Id']
Ibg_9 = Ants_v2_2_4_Vbg_neg10V_Vds_0tm5V[' Ibg']

Ants_v2_2_4_Vbg_5V_Vds_0tm5V = pd.read_csv('./Pre_transfer/Ants_v2_2_4_Vbg_5V_Vds_0tm5V.csv')
Vd_10 = Ants_v2_2_4_Vbg_5V_Vds_0tm5V[" Vd"]
Id_10 = Ants_v2_2_4_Vbg_5V_Vds_0tm5V[' Id']
Ibg_10 = Ants_v2_2_4_Vbg_5V_Vds_0tm5V[' Ibg']

Ants_v2_2_4_Vbg_neg20V_Vds_0tm5V = pd.read_csv('./Pre_transfer/Ants_v2_2_4_Vbg_neg20V_Vds_0tm5V.csv')
Vd_11 = Ants_v2_2_4_Vbg_neg20V_Vds_0tm5V[" Vd"]
Id_11 = Ants_v2_2_4_Vbg_neg20V_Vds_0tm5V[' Id']
Ibg_11 = Ants_v2_2_4_Vbg_neg20V_Vds_0tm5V[' Ibg']

# %% [markdown]
# # Sentaurus
#
# ____________

# %%
CNT_SiO2_neg_gate = pd.read_csv('./CNT_SiO2_neg_gate.csv')
x_sim = CNT_SiO2_neg_gate["x"]
y_sim = CNT_SiO2_neg_gate['y']

CNT_SiO2_pos_gate = pd.read_csv('./CNT_SiO2_pos_gate.csv')
x_sim1 = CNT_SiO2_pos_gate["x"]
y_sim1 = CNT_SiO2_pos_gate['y']

# %%
fig = plt.figure(figsize=(3.4,3.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('CNT $L_{ch}$ = 38 $\mu$m, $V_{ds}$ = 1 V')


ax1.plot(Vbg_3,abs((Id_3/1e-6)), '-', lw = 3, c = 'midnightblue', alpha=1, label = 'Experiment')

ax1.plot(x_sim,abs(y_sim/1e-6), '-', lw = 2, c = 'orange', alpha=1, label = 'Simulation')
ax1.plot(x_sim1,abs(y_sim1/1e-6), '-', lw = 2, c = 'orange', alpha=1)

ax1.set_ylabel('$I_d$ [$\mu$A]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('$V_{bg}$ [V]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
#ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
#ax1.set_xlim([40, 60])
#ax1.set_ylim([0, 4.5])

plt.legend(loc = 'best', fontsize = 9.5)

plt.savefig("sim_comp_lin.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.4,3.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('CNT $L_{ch}$ = 38 $\mu$m, $V_{ds}$ = 1 V')


ax1.plot(Vbg_3,abs((Id_3)), '-', lw = 3, c = 'midnightblue', alpha=1, label = 'Experiment')

ax1.plot(x_sim,abs(y_sim), '-', lw = 3, c = 'orange', alpha=1, label = 'Simulation')
ax1.plot(x_sim1,abs(y_sim1), '-', lw = 3, c = 'orange', alpha=1)

ax1.set_ylabel('$I_d$ [A]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('$V_{bg}$ [V]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
#ax1.set_xlim([-25, 50])
ax1.set_ylim([5e-11, 2e-6])

plt.legend(loc = 'best', fontsize = 9.5)

plt.savefig("sim_comp_log.png",bbox_inches='tight', dpi = 300)
plt.show()

# %% [markdown]
# # Experimental
# _______________

# %%
fig = plt.figure(figsize=(3.4,3.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('CNT $L_{ch}$ = 38 $\mu$m, $V_{ds}$ = 2 V')


ax1.plot(Vbg_4,abs((Id_4)), '-', lw = 3, c = 'seagreen', alpha=1, label = 'Drain current')

ax1.plot(Vbg_4,abs(Ibg_4), '--', lw = 2, c = 'steelblue', alpha=1, label = 'Back-gate current')


ax1.set_ylabel('|Current| [A]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('$V_{bg}$ [V]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
#ax1.set_xlim([40, 60])
#ax1.set_ylim([0, 4.5])

plt.legend(loc = 'best', fontsize = 9.5)

plt.savefig("Ants_v2_2_4_Vds_2V_transfer_curve_pre_transfer.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(6.4,6.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('CNT $L_{ch}$ = 38 $\mu$m')

ax1.plot(Vbg_1,abs((Id_1)), '-', lw = 3, c = 'seagreen', alpha=1, label = 'V$_{ds}$ = 0.1 V')
ax1.plot(Vbg_2,abs((Id_2)), '-', lw = 3, c = 'rebeccapurple', alpha=1, label = 'V$_{ds}$ = 0.5 V')
ax1.plot(Vbg_3,abs((Id_3)), '-', lw = 3, c = 'steelblue', alpha=1, label = 'V$_{ds}$ = 1 V')
ax1.plot(Vbg_4,abs((Id_4)), '-', lw = 3, c = 'crimson', alpha=1, label = 'V$_{ds}$ = 2 V')

#ax1.plot(Vbg_1,abs((Ibg_1)), ':', lw = 3, c = 'seagreen', alpha=1, label = 'V$_{ds}$ = 0.1 V')
#ax1.plot(Vbg_2,abs((Ibg_2)), ':', lw = 3, c = 'rebeccapurple', alpha=1, label = 'V$_{ds}$ = 0.5 V')
#ax1.plot(Vbg_3,abs((Ibg_3)), ':', lw = 3, c = 'steelblue', alpha=1, label = 'V$_{ds}$ = 1 V')
#ax1.plot(Vbg_4,abs((Ibg_4)), ':', lw = 3, c = 'crimson', alpha=1, label = 'V$_{ds}$ = 2 V')


ax1.set_ylabel('I$_d$ [A]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('$V_{bg}$ [V]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
ax1.set_xlim([-50, 50])
#ax1.set_ylim([0, 4.5])

plt.legend(loc = 'best', fontsize = 12.5)

plt.savefig("Ants_v2_2_4_all_gates_pre_transfer.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(6.4,6.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('CNT $L_{ch}$ = 38 $\mu$m')

ax1.plot(Vbg_1,abs((Id_1)), '-', lw = 3, c = 'seagreen', alpha=1, label = 'V$_{ds}$ = 0.1 V')
ax1.plot(Vbg_2,abs((Id_2)), '-', lw = 3, c = 'rebeccapurple', alpha=1, label = 'V$_{ds}$ = 0.5 V')
ax1.plot(Vbg_3,abs((Id_3)), '-', lw = 3, c = 'steelblue', alpha=1, label = 'V$_{ds}$ = 1 V')
ax1.plot(Vbg_4,abs((Id_4)), '-', lw = 3, c = 'crimson', alpha=1, label = 'V$_{ds}$ = 2 V')

#ax1.plot(Vbg_1,abs((Ibg_1)), ':', lw = 3, c = 'seagreen', alpha=1, label = 'V$_{ds}$ = 0.1 V')
#ax1.plot(Vbg_2,abs((Ibg_2)), ':', lw = 3, c = 'rebeccapurple', alpha=1, label = 'V$_{ds}$ = 0.5 V')
#ax1.plot(Vbg_3,abs((Ibg_3)), ':', lw = 3, c = 'steelblue', alpha=1, label = 'V$_{ds}$ = 1 V')
#ax1.plot(Vbg_4,abs((Ibg_4)), ':', lw = 3, c = 'crimson', alpha=1, label = 'V$_{ds}$ = 2 V')


ax1.set_ylabel('I$_d$ [A]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('$V_{bg}$ [V]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
#ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
ax1.set_xlim([-50, 50])
#ax1.set_ylim([0, 4.5])

plt.legend(loc = 'best', fontsize = 12.5)

plt.savefig("Ants_v2_2_4_all_gates_pre_transfer_linear.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
len(Id_5)
# Out:
# 1600

# %%
fig = plt.figure(figsize=(6.4,6.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('CNT $L_{ch}$ = 38 $\mu$m')

ax1.plot(Vbg_5[0:800],abs((Id_5[0:800])), '-', lw = 3, c = 'seagreen', alpha=1, label = 'Pos-to-neg sweep')
ax1.plot(Vbg_5[800:1600],abs((Id_5[800:1600])), '-', lw = 3, c = 'rebeccapurple', alpha=1, label = 'Neg-to-pos sweep')

#ax1.plot(Vbg_1,abs((Ibg_1)), ':', lw = 3, c = 'seagreen', alpha=1, label = 'V$_{ds}$ = 0.1 V')
#ax1.plot(Vbg_2,abs((Ibg_2)), ':', lw = 3, c = 'rebeccapurple', alpha=1, label = 'V$_{ds}$ = 0.5 V')
#ax1.plot(Vbg_3,abs((Ibg_3)), ':', lw = 3, c = 'steelblue', alpha=1, label = 'V$_{ds}$ = 1 V')
#ax1.plot(Vbg_4,abs((Ibg_4)), ':', lw = 3, c = 'crimson', alpha=1, label = 'V$_{ds}$ = 2 V')


ax1.set_ylabel('I$_d$ [A]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('$V_{bg}$ [V]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
#ax1.set_xlim([-50, -30])
#ax1.set_ylim([0, 4.5])

plt.legend(loc = 'best', fontsize = 12.5)

plt.savefig("hysteresis_log.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(6.4,6.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('CNT $L_{ch}$ = 38 $\mu$m')

ax1.plot(Vbg_5[0:800],abs((Id_5[0:800]/1e-6/0.005)), '-', lw = 3, c = 'seagreen', alpha=1, label = 'Pos-to-neg sweep')
ax1.plot(Vbg_5[800:1600],abs((Id_5[800:1600]/1e-6/0.005)), '-', lw = 3, c = 'rebeccapurple', alpha=1, label = 'Neg-to-pos sweep')


#ax1.plot(Vbg_1,abs((Ibg_1)), ':', lw = 3, c = 'seagreen', alpha=1, label = 'V$_{ds}$ = 0.1 V')
#ax1.plot(Vbg_2,abs((Ibg_2)), ':', lw = 3, c = 'rebeccapurple', alpha=1, label = 'V$_{ds}$ = 0.5 V')
#ax1.plot(Vbg_3,abs((Ibg_3)), ':', lw = 3, c = 'steelblue', alpha=1, label = 'V$_{ds}$ = 1 V')
#ax1.plot(Vbg_4,abs((Ibg_4)), ':', lw = 3, c = 'crimson', alpha=1, label = 'V$_{ds}$ = 2 V')


ax1.set_ylabel('I$_d$ [$\mu$A/$\mu$m]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('$V_{bg}$ [V]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
#ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
#ax1.set_xlim([-50, -30])
#ax1.set_ylim([0, 4.5])

plt.legend(loc = 'best', fontsize = 12.5)

plt.savefig("hysteresis_lin.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.4,3.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('CNT $L_{ch}$ = 38 $\mu$m')


ax1.plot(Vd_6,((Id_6/1e-6)), '-', lw = 3, c = 'seagreen', alpha=1, label = '$V_{bg}$ = 0 V')
ax1.plot(Vd_7,((Id_7/1e-6)), '-', lw = 3, c = 'steelblue', alpha=1, label = '$V_{bg}$ = -5 V')
ax1.plot(Vd_8,((Id_8/1e-6)), '-', lw = 3, c = 'crimson', alpha=1, label = '$V_{bg}$ = -7.5 V')
#ax1.plot(Vd_9,((Id_9/1e-6)), '-', lw = 3, c = 'rebeccapurple', alpha=1, label = '$V_{bg}$ = -10 V')
ax1.plot(Vd_11,((Id_11/1e-6)), '-', lw = 3, c = 'orange', alpha=1, label = '$V_{bg}$ = -20 V')

ax1.set_ylabel('$I_d$ [$\mu$A]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('$V_{d}$ [V]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
#ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
ax1.set_xlim([0, -5])
ax1.set_ylim([0, -2])

plt.legend(loc = 'best', fontsize = 9.5)

plt.savefig("Ants_v2_2_4_Vds_output_curves_pre_transfer.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.4,3.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('CNT $L_{ch}$ = 38 $\mu$m')


ax1.plot(Vd_6,(abs(Id_6/1e-6)), '-', lw = 3, c = 'seagreen', alpha=1, label = '$V_{bg}$ = 0 V')
ax1.plot(Vd_7,(abs(Id_7/1e-6)), '-', lw = 3, c = 'steelblue', alpha=1, label = '$V_{bg}$ = -5 V')
ax1.plot(Vd_8,(abs(Id_8/1e-6)), '-', lw = 3, c = 'crimson', alpha=1, label = '$V_{bg}$ = -7.5 V')
#ax1.plot(Vd_9,((Id_9/1e-6)), '-', lw = 3, c = 'rebeccapurple', alpha=1, label = '$V_{bg}$ = -10 V')
ax1.plot(Vd_11,(abs(Id_11/1e-6)), '-', lw = 3, c = 'orange', alpha=1, label = '$V_{bg}$ = -20 V')

ax1.set_ylabel('$I_d$ [$\mu$A]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('$V_{d}$ [V]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
ax1.set_xlim([0, -5])
ax1.set_ylim([1e-2, 2])

plt.legend(loc = 'best', fontsize = 9.5)

plt.savefig("Ants_v2_2_4_Vds_output_curves_pre_transfer_log.png",bbox_inches='tight', dpi = 300)
plt.show()

# %% [markdown]
# # Raman
#
# _____________

# %% [markdown]
# ## Pre-transfer
#
# ________

# %%
Ants_v2_2_4_fitted = pd.read_csv('./Ants_v2_2_4_Raman/Ants_v2_2_4_fitted.csv')
x = Ants_v2_2_4_fitted["x"]
y1 = Ants_v2_2_4_fitted['y1']
y2 = Ants_v2_2_4_fitted['y2']
y3 = Ants_v2_2_4_fitted['y3']

Ants_v2_2_4_sum = pd.read_csv('./Ants_v2_2_4_Raman/Ants_v2_2_4_sum.csv')
x1 = Ants_v2_2_4_sum["x"]
s1 = Ants_v2_2_4_sum['s1']

# %%
fig = plt.figure(figsize=(6.4,6.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('CNT Raman pre-transfer')

ax1.plot(x, y1, 'o', ms = 3, c = 'black', alpha=1, label = 'Raw spectrum')
ax1.plot(x, y2, '-', lw = 2, c = 'crimson', alpha=1, label = '$G^-$ peak')
ax1.plot(x, y3, '-', lw = 2, c = 'b', alpha=1, label = '$G^-$ peak')
ax1.plot(x1, s1, '-', lw = 2, c = 'seagreen', alpha=1, label = 'Combined fit')


ax1.set_ylabel('Intensity [a.u.]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('Raman shift [cm$^{-1}$]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
#ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
ax1.set_xlim([1500, 1700])
#ax1.set_ylim([0, 4.5])

plt.legend(loc = 'best', fontsize = 12.5)

plt.savefig("Ramanero.png",bbox_inches='tight', dpi = 300)
plt.show()

# %% [markdown]
# |      | Pre-transfer | Post-transfer |
# | ----------- | ----------- |----------------|
# | $G^+$ position      |1597.611146  | x |
# | $G^+$ FWHM   |    9.85754     | x|
# | $G^+$ intensity   |    2393.37     | x|
# | $G^-$ position      |1586.148432  | x |
# | $G^-$ FWHM   |    26.2336    | x|
# | $G^-$ intensity   |    26.2336    | x|

# %% [markdown]
# # AFM
#
# ________________

# %% [markdown]
# ## Pre-transfer
#
# __________

# %%
line_profile_CNT = pd.read_csv('./Ants_v2_2_4_AFM/line_profile_CNT.csv')
xa = line_profile_CNT["x"]
ya = line_profile_CNT['y']

# %%
fig = plt.figure(figsize=(4.4,2.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('CNT AFM scan pre-transfer')

ax1.plot(xa/1e-9, ya/1e-9, '-', lw = 3, c = 'steelblue', alpha=1, label = 'Raw spectrum')



ax1.set_ylabel('Height [nm]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('Distance [nm]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
#ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
#ax1.set_xlim([1500, 1700])
#ax1.set_ylim([0, 4.5])

#plt.legend(loc = 'best', fontsize = 12.5)

plt.savefig("AFMero.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(4,4))
axes = fig.add_subplot(111)
fig.canvas.draw()

img = mpimg.imread('./Ants_v2_2_4_AFM/Ants_v2_2_4.png')
lum_img = img[:, :, 0]

imgplot = plt.imshow(lum_img,clim=(0,0.12),interpolation="lanczos", cmap = 'RdGy_r')

#a=axes.get_xticks().tolist()
#labels_X = ['wha','0', '250', '500', '750', '1000', '1250', '1500', '1750', '2000']
#labels_Y = ['wha','0', '250', '500', '750', '1000', '1250', '1500', '1750', '2000']
#axes.set_xticklabels(labels_X, fontsize = 12)
#axes.set_yticklabels(labels_Y, fontsize = 12)
#plt.yticks([1334, 1134, 934, 734, 534, 334, 134])
#plt.xticks([1, 201, 401, 601, 801, 1001, 1201 ])
plt.xlim([650, 1050])
plt.ylim([1250, 850])

plt.ylabel('Distance [nm]', fontsize = 12)
plt.xlabel('Distance [nm]', fontsize = 12)

cbar = fig.colorbar(imgplot,fraction=0.046, pad=0.04)
#cbar.set_ticklabels(['0', '48.25', '96.5'])
cbar.set_label('Height (nm)', fontsize = 12)

plt.savefig("Ants_v2_2_4_height_map.png",bbox_inches='tight', dpi = 300)

# %%
fig = plt.figure(figsize=(4,4))
axes = fig.add_subplot(111)
fig.canvas.draw()

img = mpimg.imread('./Ants_v2_2_4_AFM/Ants_v2_2_4_large.png')
lum_img = img[:, :, 0]

imgplot = plt.imshow(lum_img,clim=(0,0.1),interpolation="lanczos", cmap = 'RdGy_r')

#a=axes.get_xticks().tolist()
#labels_X = ['wha','0', '250', '500', '750', '1000', '1250', '1500', '1750', '2000']
#labels_Y = ['wha','0', '250', '500', '750', '1000', '1250', '1500', '1750', '2000']
#axes.set_xticklabels(labels_X, fontsize = 12)
#axes.set_yticklabels(labels_Y, fontsize = 12)
#plt.yticks([1334, 1134, 934, 734, 534, 334, 134])
#plt.xticks([1, 201, 401, 601, 801, 1001, 1201 ])
plt.xlim([400, 900])
plt.ylim([800, 300])

plt.ylabel('Distance [nm]', fontsize = 12)
plt.xlabel('Distance [nm]', fontsize = 12)

cbar = fig.colorbar(imgplot,fraction=0.046, pad=0.04)
#cbar.set_ticklabels(['0', '48.25', '96.5'])
cbar.set_label('Height (nm)', fontsize = 12)

plt.savefig("Ants_v2_2_4_large_height_map.png",bbox_inches='tight', dpi = 300)

# %% [markdown]
# # Post-transfer
#
# ________________________

# %%
hBN_thickness = pd.read_csv('./Ants_v2_2_4_AFM/hBN_thickness.csv')
xh = hBN_thickness["x"]
yh = hBN_thickness['y']

# %%
fig = plt.figure(figsize=(6,6))
axes = fig.add_subplot(111)
fig.canvas.draw()

img = mpimg.imread('./Ants_v2_2_4_AFM/hBN_scan.png')
lum_img = img[:, :, 0]

imgplot = plt.imshow(lum_img,clim=(0,1),interpolation="lanczos", cmap = 'coolwarm')

#a=axes.get_xticks().tolist()
#labels_X = ['wha','0', '250', '500', '750', '1000', '1250', '1500', '1750', '2000']
#labels_Y = ['wha','0', '250', '500', '750', '1000', '1250', '1500', '1750', '2000']
#axes.set_xticklabels(labels_X, fontsize = 12)
#axes.set_yticklabels(labels_Y, fontsize = 12)
#plt.yticks([1334, 1134, 934, 734, 534, 334, 134])
#plt.xticks([1, 201, 401, 601, 801, 1001, 1201 ])
#plt.xlim([400, 900])
#plt.ylim([800, 300])

plt.ylabel('Distance [nm]', fontsize = 12)
plt.xlabel('Distance [nm]', fontsize = 12)

cbar = fig.colorbar(imgplot,fraction=0.046, pad=0.04)
#cbar.set_ticklabels(['0', '48.25', '96.5'])
cbar.set_label('Height (nm)', fontsize = 12)

plt.savefig("Ants_v2_2_4_hBN_map.png",bbox_inches='tight', dpi = 300)

# %%
fig = plt.figure(figsize=(4.4,2.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('h-BN AFM scan post-transfer')

ax1.plot(xh/1e-9, yh/1e-9, '-', lw = 3, c = 'forestgreen', alpha=1, label = 'Raw spectrum')



ax1.set_ylabel('Height [nm]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('Distance [nm]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
#ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
#ax1.set_xlim([1500, 1700])
#ax1.set_ylim([0, 4.5])

#plt.legend(loc = 'best', fontsize = 12.5)

plt.savefig("AFMero_post.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
Ants_v2_2_4_Vbg_hysteretic60V_Vds_0p1V_post_transfer = pd.read_csv('./Post_transfer/Ants_v2_2_4_Vbg_hysteretic60V_Vds_0p1V_post_transfer.csv')
Vbg_1t = Ants_v2_2_4_Vbg_hysteretic60V_Vds_0p1V_post_transfer[" Vbg"]
Id_1t = Ants_v2_2_4_Vbg_hysteretic60V_Vds_0p1V_post_transfer[' Id']
Ibg_1t = Ants_v2_2_4_Vbg_hysteretic60V_Vds_0p1V_post_transfer[' Ibg']

Ants_v2_2_4_Vbg_hysteretic60V_Vds_0p5V_post_transfer = pd.read_csv('./Post_transfer/Ants_v2_2_4_Vbg_hysteretic60V_Vds_0p5V_post_transfer.csv')
Vbg_2t = Ants_v2_2_4_Vbg_hysteretic60V_Vds_0p5V_post_transfer[" Vbg"]
Id_2t = Ants_v2_2_4_Vbg_hysteretic60V_Vds_0p5V_post_transfer[' Id']
Ibg_2t = Ants_v2_2_4_Vbg_hysteretic60V_Vds_0p5V_post_transfer[' Ibg']

Ants_v2_2_4_Vbg_hysteretic60V_Vds_1V_post_transfer = pd.read_csv('./Post_transfer/Ants_v2_2_4_Vbg_hysteretic60V_Vds_1V_post_transfer.csv')
Vbg_3t = Ants_v2_2_4_Vbg_hysteretic60V_Vds_1V_post_transfer[" Vbg"]
Id_3t = Ants_v2_2_4_Vbg_hysteretic60V_Vds_1V_post_transfer[' Id']
Ibg_3t = Ants_v2_2_4_Vbg_hysteretic60V_Vds_1V_post_transfer[' Ibg']

Ants_v2_2_4_Vbg_hysteretic60V_Vds_2V_post_transfer = pd.read_csv('./Post_transfer/Ants_v2_2_4_Vbg_hysteretic60V_Vds_2V_post_transfer.csv')
Vbg_4t = Ants_v2_2_4_Vbg_hysteretic60V_Vds_2V_post_transfer[" Vbg"]
Id_4t = Ants_v2_2_4_Vbg_hysteretic60V_Vds_2V_post_transfer[' Id']
Ibg_4t = Ants_v2_2_4_Vbg_hysteretic60V_Vds_2V_post_transfer[' Ibg']

##################IVs##############

Ants_v2_2_4_Vbg_neg60V_Vds_0to5V_post_transfer = pd.read_csv('./Post_transfer/Ants_v2_2_4_Vbg_neg60V_Vds_0to5V_post_transfer.csv')
Vd_5t = Ants_v2_2_4_Vbg_neg60V_Vds_0to5V_post_transfer[" Vd"]
Id_5t = Ants_v2_2_4_Vbg_neg60V_Vds_0to5V_post_transfer[' Id']
Ibg_5t = Ants_v2_2_4_Vbg_neg60V_Vds_0to5V_post_transfer[' Ibg']

Ants_v2_2_4_Vbg_neg40V_Vds_0to5V_post_transfer = pd.read_csv('./Post_transfer/Ants_v2_2_4_Vbg_neg40V_Vds_0to5V_post_transfer.csv')
Vd_6t = Ants_v2_2_4_Vbg_neg40V_Vds_0to5V_post_transfer[" Vd"]
Id_6t = Ants_v2_2_4_Vbg_neg40V_Vds_0to5V_post_transfer[' Id']
Ibg_6t = Ants_v2_2_4_Vbg_neg40V_Vds_0to5V_post_transfer[' Ibg']

Ants_v2_2_4_Vbg_neg20V_Vds_0to5V_post_transfer = pd.read_csv('./Post_transfer/Ants_v2_2_4_Vbg_neg20V_Vds_0to5V_post_transfer.csv')
Vd_7t = Ants_v2_2_4_Vbg_neg20V_Vds_0to5V_post_transfer[" Vd"]
Id_7t = Ants_v2_2_4_Vbg_neg20V_Vds_0to5V_post_transfer[' Id']
Ibg_7t = Ants_v2_2_4_Vbg_neg20V_Vds_0to5V_post_transfer[' Ibg']

Ants_v2_2_4_Vbg_neg10V_Vds_0to5V_post_transfer = pd.read_csv('./Post_transfer/Ants_v2_2_4_Vbg_neg10V_Vds_0to5V_post_transfer.csv')
Vd_8t = Ants_v2_2_4_Vbg_neg10V_Vds_0to5V_post_transfer[" Vd"]
Id_8t = Ants_v2_2_4_Vbg_neg10V_Vds_0to5V_post_transfer[' Id']
Ibg_8t = Ants_v2_2_4_Vbg_neg10V_Vds_0to5V_post_transfer[' Ibg']

Ants_v2_2_4_Vbg_neg5V_Vds_0to5V_post_transfer = pd.read_csv('./Post_transfer/Ants_v2_2_4_Vbg_neg5V_Vds_0to5V_post_transfer.csv')
Vd_9t = Ants_v2_2_4_Vbg_neg5V_Vds_0to5V_post_transfer[" Vd"]
Id_9t = Ants_v2_2_4_Vbg_neg5V_Vds_0to5V_post_transfer[' Id']
Ibg_9t = Ants_v2_2_4_Vbg_neg5V_Vds_0to5V_post_transfer[' Ibg']

Ants_v2_2_4_Vbg_neg2V_Vds_0to5V_post_transfer = pd.read_csv('./Post_transfer/Ants_v2_2_4_Vbg_neg2V_Vds_0to5V_post_transfer.csv')
Vd_10t = Ants_v2_2_4_Vbg_neg2V_Vds_0to5V_post_transfer[" Vd"]
Id_10t = Ants_v2_2_4_Vbg_neg2V_Vds_0to5V_post_transfer[' Id']
Ibg_10t = Ants_v2_2_4_Vbg_neg2V_Vds_0to5V_post_transfer[' Ibg']

# %%
fig = plt.figure(figsize=(3.4,3.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('CNT $L_{ch}$ = 38 $\mu$m, $V_{ds}$ = 1 V')


ax1.plot(Vbg_3t[400:800],abs((Id_3t[400:800])), '-', lw = 3, c = 'midnightblue', alpha=1, label = 'Experiment')

ax1.plot(x_sim,abs(y_sim), '-', lw = 3, c = 'orange', alpha=1, label = 'Simulation')
ax1.plot(x_sim1,abs(y_sim1), '-', lw = 3, c = 'orange', alpha=1)

ax1.set_ylabel('$I_d$ [A]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('$V_{bg}$ [V]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
#ax1.set_xlim([-25, 50])
#ax1.set_ylim([5e-11, 2e-6])

plt.legend(loc = 'best', fontsize = 9.5)

plt.savefig("sim_comp_log_post_transfer.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.4,3.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('CNT $L_{ch}$ = 38 $\mu$m')

ax1.plot(Vbg_1t[400:800],abs((Id_1t[400:800])), '-', lw = 1.5, c = 'seagreen', alpha=1, label = 'V$_{ds}$ = 0.1 V')
ax1.plot(Vbg_2t[400:800],abs((Id_2t[400:800])), '-', lw = 1.5, c = 'rebeccapurple', alpha=1, label = 'V$_{ds}$ = 0.5 V')
ax1.plot(Vbg_3t[400:800],abs((Id_3t[400:800])), '-', lw = 1.5, c = 'steelblue', alpha=1, label = 'V$_{ds}$ = 1 V')
ax1.plot(Vbg_4t[400:800],abs((Id_4t[400:800])), '-', lw = 1.5, c = 'crimson', alpha=1, label = 'V$_{ds}$ = 2 V')

#ax1.plot(Vbg_1,abs((Ibg_1)), ':', lw = 3, c = 'seagreen', alpha=1, label = 'V$_{ds}$ = 0.1 V')
#ax1.plot(Vbg_2,abs((Ibg_2)), ':', lw = 3, c = 'rebeccapurple', alpha=1, label = 'V$_{ds}$ = 0.5 V')
#ax1.plot(Vbg_3,abs((Ibg_3)), ':', lw = 3, c = 'steelblue', alpha=1, label = 'V$_{ds}$ = 1 V')
#ax1.plot(Vbg_4,abs((Ibg_4)), ':', lw = 3, c = 'crimson', alpha=1, label = 'V$_{ds}$ = 2 V')


ax1.set_ylabel('I$_d$ [A]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('$V_{bg}$ [V]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
#ax1.set_xlim([-50, 50])
#ax1.set_ylim([0, 4.5])

plt.legend(loc = 'best', fontsize = 12.5)

plt.savefig("Ants_v2_2_4_all_gates_post_transfer.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.4,3.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('CNT $L_{ch}$ = 38 $\mu$m')


ax1.plot(Vbg_3,abs((Id_3)), '-', lw = 2, c = 'rebeccapurple', alpha=1, label = 'Pre')
ax1.plot(Vbg_3t[400:800],abs((Id_3t[400:800])), '-', lw = 2, c = 'crimson', alpha=1, label = 'Post')



ax1.set_ylabel('I$_d$ [A]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('$V_{bg}$ [V]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
#ax1.set_xlim([-50, 50])
#ax1.set_ylim([0, 4.5])

plt.legend(loc = 'best', fontsize = 12.5)

plt.savefig("Ants_v2_2_4_all_gates_transfer_compo.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(7.4,3.4))

fig.canvas.draw()

#ax1 = fig.add_subplot(111)

ax1.set_title('Forward sweep')
ax2.set_title('Reverse sweep')

ax1.plot(Vbg_1t[0:400],abs((Id_1t[0:400])), '-', lw = 2, c = 'seagreen', alpha=1, label = 'V$_{ds}$ = 0.1 V')
ax1.plot(Vbg_2t[0:400],abs((Id_2t[0:400])), '-', lw = 2, c = 'chocolate', alpha=1, label = 'V$_{ds}$ = 0.5 V')
ax1.plot(Vbg_3t[0:400],abs((Id_3t[0:400])), '-', lw = 2, c = 'royalblue', alpha=1, label = 'V$_{ds}$ = 1 V')
ax1.plot(Vbg_4t[0:400],abs((Id_4t[0:400])), '-', lw = 2, c = 'darkviolet', alpha=1, label = 'V$_{ds}$ = 2 V')

ax2.plot(Vbg_1t[400:800],abs((Id_1t[400:800])), '-', lw = 2, c = 'seagreen', alpha=1, label = 'V$_{ds}$ = 0.1 V')
ax2.plot(Vbg_2t[400:800],abs((Id_2t[400:800])), '-', lw = 2, c = 'chocolate', alpha=1, label = 'V$_{ds}$ = 0.5 V')
ax2.plot(Vbg_3t[400:800],abs((Id_3t[400:800])), '-', lw = 2, c = 'royalblue', alpha=1, label = 'V$_{ds}$ = 1 V')
ax2.plot(Vbg_4t[400:800],abs((Id_4t[400:800])), '-', lw = 2, c = 'darkviolet', alpha=1, label = 'V$_{ds}$ = 2 V')


ax1.set_ylabel('I$_d$ [A]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('$V_{bg}$ [V]', fontsize = 13.5, fontname = 'Consolas')

ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
#ax1.set_xlim([-50, 50])
ax1.set_ylim([5e-12, 1e-6])
ax2.set_ylim([5e-12, 1e-6])
ax2.set_yscale('log')
ax2.tick_params(which = 'both', direction = 'in')
plt.setp(ax2.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax2.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')

#plt.legend(loc = 'best', fontsize = 12.5)

plt.savefig("Ants_v2_2_4_all_hysteretic_transfer_compo.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.4,3.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('CNT $L_{ch}$ = 38 $\mu$m')


#ax1.plot(Vd_5t,((Id_5t/1e-6)), '-', lw = 1.5, c = 'seagreen', alpha=1, label = '$V_{bg}$ = -60 V')
ax1.plot(Vd_6t,((Id_6t/1e-6)), '-', lw = 1.5, c = 'green', alpha=1, label = '$V_{bg}$ = -40 V')
ax1.plot(Vd_7t,((Id_7t/1e-6)), '-', lw = 1.5, c = 'darkviolet', alpha=1, label = '$V_{bg}$ = -20 V')
ax1.plot(Vd_8t,((Id_8t/1e-6)), '-', lw = 1.5, c = 'cornflowerblue', alpha=1, label = '$V_{bg}$ = -10 V')
ax1.plot(Vd_9t,((Id_9t/1e-6)), '-', lw = 1.5, c = 'crimson', alpha=1, label = '$V_{bg}$ = -5 V')
#ax1.plot(Vd_10t,((Id_10t/1e-6)), '-', lw = 1.5, c = 'black', alpha=1, label = '$V_{bg}$ = -2 V')

ax1.set_ylabel('$I_d$ [$\mu$A]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('$V_{d}$ [V]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
#ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
ax1.set_xlim([0, -5])
ax1.set_ylim([0, -0.55])

plt.legend(loc = 'best', fontsize = 9.5)

plt.savefig("Ants_v2_2_4_Vds_output_curves_post_transfer.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.4,3.4))

fig.canvas.draw()

ax1 = fig.add_subplot(111)

ax1.set_title('CNT $L_{ch}$ = 38 $\mu$m')


#ax1.plot(Vd_5t,((Id_5t/1e-6)), '-', lw = 1.5, c = 'seagreen', alpha=1, label = '$V_{bg}$ = -60 V')
ax1.plot(Vd_6t,((abs(Id_6t))), '-', lw = 1.5, c = 'g', alpha=1, label = '$V_{bg}$ = -40 V')
ax1.plot(Vd_7t,((abs(Id_7t))), '-', lw = 1.5, c = 'darkviolet', alpha=1, label = '$V_{bg}$ = -20 V')
ax1.plot(Vd_8t,((abs(Id_8t))), '-', lw = 1.5, c = 'cornflowerblue', alpha=1, label = '$V_{bg}$ = -10 V')
ax1.plot(Vd_9t,((abs(Id_9t))), '-', lw = 1.5, c = 'crimson', alpha=1, label = '$V_{bg}$ = -5 V')
#ax1.plot(Vd_10t,((Id_10t/1e-6)), '-', lw = 1.5, c = 'black', alpha=1, label = '$V_{bg}$ = -2 V')

ax1.set_ylabel('$I_d$ [$\mu$A]', fontsize = 13.5, fontname = 'Consolas')
ax1.set_xlabel('$V_{d}$ [V]', fontsize = 13.5, fontname = 'Consolas')

#ax1.text(1, 3.7e-6,'$V_{ds}$ = 1 V',fontsize = 14, color = 'seagreen')
#ax1.text(-8, 2e-6,'$V_{ds}$ = 0.5 V',fontsize = 14, color = 'darkorange')
#ax1.text(-9, 0.56e-6,'$V_{ds}$ = 0.1 V',fontsize = 14, color = 'rebeccapurple')
#ax1.grid('off')
ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in')
plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12, fontname = 'Consolas')
#plt.setp(ax1.set_xlim([0,2700]))
#plt.setp(ax1.set_ylim([1e-10,3e-6]))
#plt.legend(loc='lower left', ncol=1, fontsize = 12)
#major_ticks_1 = [0, 1, 2, 3, 4]  
#ax1.set_yticks(major_ticks_1)   
#major_ticks_1 = np.arange(0, 1.21, 0.6)   
#ax1.set_yticks(major_ticks_1)  
ax1.set_xlim([0, -5])
ax1.set_ylim([0, -0.55])

plt.legend(loc = 'best', fontsize = 9.5)

plt.savefig("Ants_v2_2_4_Vds_output_curves_post_transfer_log.png",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# C:\Users\aaa\Miniconda3\lib\site-packages\ipykernel_launcher.py:36: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# C:\Users\aaa\Miniconda3\lib\site-packages\ipykernel_launcher.py:36: UserWarning: Attempted to set non-positive top ylim on a log-scaled axis.
# Invalid limit will be ignored.
